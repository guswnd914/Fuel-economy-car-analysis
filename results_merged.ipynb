# %% [markdown]
# # Results with Merged Dataset
# #### Q5: For all of the models that were produced in 2008 that are still being produced now, how much has the mpg improved and which vehicle improved the most?
# Remember to use your new dataset, `combined_dataset.csv`. You should've created this data file in the previous section: *Merging Datasets*.

# %%
# load dataset
import pandas as pd
df = pd.read_csv('combined_dataset.csv')

# %% [markdown]
# ### 1. Create a new dataframe, `model_mpg`, that contain the mean combined mpg values in 2008 and 2018 for each unique model
#
# To do this, group by `model` and find the mean `cmb_mpg_2008` and mean `cmb_mpg` for each.

# %%
model_mpg = df.groupby(['model_2008','model'])['cmb_mpg_2008','cmb_mpg'].mean()

# %%
model_mpg.head()
# Out:
#                       cmb_mpg_2008    cmb_mpg
# model_2008 model
# ACURA RDX  ACURA RDX     19.000000  22.500000
# AUDI A3    AUDI A3       23.333333  28.000000
# AUDI A4    AUDI A4       21.000000  27.000000
# AUDI A6    AUDI A6       19.666667  25.666667
# AUDI A8 L  AUDI A8 L     16.500000  22.000000

# %% [markdown]
# ### 2. Create a new column, `mpg_change`, with the change in mpg
# Subtract the mean mpg in 2008 from that in 2018 to get the change in mpg

# %%
model_mpg['mpg_change'] = model_mpg['cmb_mpg'] - model_mpg['cmb_mpg_2008']

# %%
model_mpg
# Out:
#                                                          cmb_mpg_2008  \
# model_2008                  model
# ACURA RDX                   ACURA RDX                       19.000000
# AUDI A3                     AUDI A3                         23.333333
# AUDI A4                     AUDI A4                         21.000000
# AUDI A6                     AUDI A6                         19.666667
# AUDI A8 L                   AUDI A8 L                       16.500000
# AUDI Q7                     AUDI Q7                         15.000000
# AUDI S4                     AUDI S4                         15.500000
# AUDI S5                     AUDI S5                         16.000000
# AUDI TT Coupe               AUDI TT Coupe                   21.666667
# AUDI TT Roadster            AUDI TT Roadster                21.333333
# BMW 750i                    BMW 750i                        20.000000
# BMW Alpina B7               BMW Alpina B7                   18.000000
# BMW M6 Convertible          BMW M6 Convertible              14.000000
# CADILLAC CTS                CADILLAC CTS                    20.000000
# CADILLAC Escalade           CADILLAC Escalade               14.000000
# CHEVROLET Corvette          CHEVROLET Corvette              18.000000
# CHEVROLET Equinox           CHEVROLET Equinox               19.000000
# CHEVROLET Impala            CHEVROLET Impala                20.500000
# CHEVROLET Malibu            CHEVROLET Malibu                22.333333
# CHEVROLET Silverado 15      CHEVROLET Silverado 15          16.000000
# CHEVROLET Tahoe 1500        CHEVROLET Tahoe 1500            14.000000
# CHRYSLER 300                CHRYSLER 300                    18.800000
# CHRYSLER Pacifica           CHRYSLER Pacifica               17.333333
# DODGE Challenger            DODGE Challenger                15.000000
# DODGE Charger               DODGE Charger                   18.800000
# DODGE Durango               DODGE Durango                   15.200000
# FORD F150                   FORD F150                       15.000000
# FORD Fusion                 FORD Fusion                     21.333333
# GMC Acadia                  GMC Acadia                      18.500000
# GMC Sierra 15               GMC Sierra 15                   15.200000
# ...                                                               ...
# KIA Sportage                KIA Sportage                    20.600000
# LEXUS LX 570                LEXUS LX 570                    14.000000
# MASERATI Granturismo        MASERATI Granturismo            17.000000
# MAZDA 3                     MAZDA 3                         24.400000
# MAZDA CX-9                  MAZDA CX-9                      17.500000
# MERCEDES-BENZ C300          MERCEDES-BENZ C300              18.000000
# MERCEDES-BENZ SL550         MERCEDES-BENZ SL550             16.000000
# NISSAN Armada               NISSAN Armada                   14.000000
# NISSAN Versa                NISSAN Versa                    28.000000
# PORSCHE 911 Turbo           PORSCHE 911 Turbo               18.000000
# PORSCHE 911 Turbo Cabriolet PORSCHE 911 Turbo Cabriolet     18.000000
# PORSCHE Boxster             PORSCHE Boxster                 22.000000
# PORSCHE Boxster S           PORSCHE Boxster S               21.000000
# PORSCHE Cayenne S           PORSCHE Cayenne S               15.000000
# SUBARU Forester             SUBARU Forester                 21.500000
# SUBARU Impreza              SUBARU Impreza                  21.750000
# SUBARU Legacy               SUBARU Legacy                   21.125000
# TOYOTA 4Runner              TOYOTA 4Runner                  16.750000
# TOYOTA Avalon               TOYOTA Avalon                   22.000000
# TOYOTA Camry                TOYOTA Camry                    24.250000
# TOYOTA Corolla              TOYOTA Corolla                  30.000000
# TOYOTA Land Cruiser         TOYOTA Land Cruiser             15.000000
# TOYOTA RAV4                 TOYOTA RAV4                     22.250000
# TOYOTA Sequoia              TOYOTA Sequoia                  14.750000
# TOYOTA Tundra               TOYOTA Tundra                   15.400000
# TOYOTA Yaris                TOYOTA Yaris                    31.500000
# VOLKSWAGEN Jetta            VOLKSWAGEN Jetta                24.166667
# VOLKSWAGEN Passat           VOLKSWAGEN Passat               21.250000
# VOLVO S60                   VOLVO S60                       21.333333
# VOLVO XC 90                 VOLVO XC 90                     15.666667
#
#                                                            cmb_mpg  mpg_change
# model_2008                  model
# ACURA RDX                   ACURA RDX                    22.500000    3.500000
# AUDI A3                     AUDI A3                      28.000000    4.666667
# AUDI A4                     AUDI A4                      27.000000    6.000000
# AUDI A6                     AUDI A6                      25.666667    6.000000
# AUDI A8 L                   AUDI A8 L                    22.000000    5.500000
# AUDI Q7                     AUDI Q7                      21.000000    6.000000
# AUDI S4                     AUDI S4                      24.000000    8.500000
# AUDI S5                     AUDI S5                      24.000000    8.000000
# AUDI TT Coupe               AUDI TT Coupe                26.000000    4.333333
# AUDI TT Roadster            AUDI TT Roadster             26.000000    4.666667
# BMW 750i                    BMW 750i                     19.500000   -0.500000
# BMW Alpina B7               BMW Alpina B7                19.000000    1.000000
# BMW M6 Convertible          BMW M6 Convertible           16.500000    2.500000
# CADILLAC CTS                CADILLAC CTS                 22.800000    2.800000
# CADILLAC Escalade           CADILLAC Escalade            17.000000    3.000000
# CHEVROLET Corvette          CHEVROLET Corvette           17.750000   -0.250000
# CHEVROLET Equinox           CHEVROLET Equinox            27.833333    8.833333
# CHEVROLET Impala            CHEVROLET Impala             21.250000    0.750000
# CHEVROLET Malibu            CHEVROLET Malibu             33.000000   10.666667
# CHEVROLET Silverado 15      CHEVROLET Silverado 15       17.312500    1.312500
# CHEVROLET Tahoe 1500        CHEVROLET Tahoe 1500         16.875000    2.875000
# CHRYSLER 300                CHRYSLER 300                 20.000000    1.200000
# CHRYSLER Pacifica           CHRYSLER Pacifica            22.000000    4.666667
# DODGE Challenger            DODGE Challenger             19.000000    4.000000
# DODGE Charger               DODGE Charger                19.750000    0.950000
# DODGE Durango               DODGE Durango                19.000000    3.800000
# FORD F150                   FORD F150                    19.545455    4.545455
# FORD Fusion                 FORD Fusion                  24.000000    2.666667
# GMC Acadia                  GMC Acadia                   21.750000    3.250000
# GMC Sierra 15               GMC Sierra 15                17.312500    2.112500
# ...                                                            ...         ...
# KIA Sportage                KIA Sportage                 23.333333    2.733333
# LEXUS LX 570                LEXUS LX 570                 15.000000    1.000000
# MASERATI Granturismo        MASERATI Granturismo         16.000000   -1.000000
# MAZDA 3                     MAZDA 3                      30.833333    6.433333
# MAZDA CX-9                  MAZDA CX-9                   23.500000    6.000000
# MERCEDES-BENZ C300          MERCEDES-BENZ C300           25.666667    7.666667
# MERCEDES-BENZ SL550         MERCEDES-BENZ SL550          20.000000    4.000000
# NISSAN Armada               NISSAN Armada                15.500000    1.500000
# NISSAN Versa                NISSAN Versa                 31.400000    3.400000
# PORSCHE 911 Turbo           PORSCHE 911 Turbo            21.000000    3.000000
# PORSCHE 911 Turbo Cabriolet PORSCHE 911 Turbo Cabriolet  21.000000    3.000000
# PORSCHE Boxster             PORSCHE Boxster              24.500000    2.500000
# PORSCHE Boxster S           PORSCHE Boxster S            23.000000    2.000000
# PORSCHE Cayenne S           PORSCHE Cayenne S            20.000000    5.000000
# SUBARU Forester             SUBARU Forester              25.666667    4.166667
# SUBARU Impreza              SUBARU Impreza               29.000000    7.250000
# SUBARU Legacy               SUBARU Legacy                26.000000    4.875000
# TOYOTA 4Runner              TOYOTA 4Runner               18.000000    1.250000
# TOYOTA Avalon               TOYOTA Avalon                24.000000    2.000000
# TOYOTA Camry                TOYOTA Camry                 30.000000    5.750000
# TOYOTA Corolla              TOYOTA Corolla               31.000000    1.000000
# TOYOTA Land Cruiser         TOYOTA Land Cruiser          15.000000    0.000000
# TOYOTA RAV4                 TOYOTA RAV4                  25.000000    2.750000
# TOYOTA Sequoia              TOYOTA Sequoia               14.500000   -0.250000
# TOYOTA Tundra               TOYOTA Tundra                15.250000   -0.150000
# TOYOTA Yaris                TOYOTA Yaris                 32.500000    1.000000
# VOLKSWAGEN Jetta            VOLKSWAGEN Jetta             30.000000    5.833333
# VOLKSWAGEN Passat           VOLKSWAGEN Passat            29.000000    7.750000
# VOLVO S60                   VOLVO S60                    27.000000    5.666667
# VOLVO XC 90                 VOLVO XC 90                  32.200000   16.533333
#
# [72 rows x 3 columns]

# %% [markdown]
# ### 3. Find the vehicle that improved the most
# Find the max mpg change, and then use query or indexing to see what model it is!

# %%
model_mpg.query('mpg_change == mpg_change.max()')
# Out:
#                          cmb_mpg_2008  cmb_mpg  mpg_change
# model_2008  model
# VOLVO XC 90 VOLVO XC 90     15.666667     32.2   16.533333

# %%
VOLVO XC90
