# %% [markdown]
# # Drawing Conclusions
# Use the space below to address questions on datasets `clean_08.csv` and `clean_18.csv`. You should've created these data files in the previous section: *Fixing Data Types Pt 3*.

# %%
# load datasets
import pandas as pd
df_08 = pd.read_csv('clean_08.csv')
df_18 = pd.read_csv('clean_18.csv')

# %% [markdown]
# ### Q1: Are more unique models using alternative sources of fuel? By how much?

# %%
num_count_08 = len(df_08.query('fuel != ["Gasoline", "Diesel", "Gas"]'))

# %%
num_count_18 = len(df_18.query('fuel != ["Gasoline", "Diesel", "Gas"]'))

# %%
"Yes, cars, not Gasoline, Diesel, and Gas, raised from {} to {} from 2008 to 2018".format(num_count_08,num_count_18)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5c0201814633> in <module>()
# ----> 1 "Yes, cars, not Gasoline, Diesel, and Gas, raised from {} to {} from 2008 to 2018".format(num_count_08,num_count_18)
#
# NameError: name 'num_count_08' is not defined

# %% [markdown]
# ### Q2: How much have vehicle classes improved in fuel economy?

# %%
df_08
# Out:
#                         model  displ  cyl    trans drive      fuel  \
# 0                   ACURA MDX    3.7    6  Auto-S5   4WD  Gasoline
# 1                   ACURA RDX    2.3    4  Auto-S5   4WD  Gasoline
# 2                    ACURA RL    3.5    6  Auto-S5   4WD  Gasoline
# 3                    ACURA TL    3.2    6  Auto-S5   2WD  Gasoline
# 4                    ACURA TL    3.5    6  Auto-S5   2WD  Gasoline
# 5                    ACURA TL    3.5    6    Man-6   2WD  Gasoline
# 6                   ACURA TSX    2.4    4    Man-6   2WD  Gasoline
# 7                   ACURA TSX    2.4    4  Auto-S5   2WD  Gasoline
# 8            ASTON MARTIN DB9    5.9   12    Man-6   2WD  Gasoline
# 9            ASTON MARTIN DB9    5.9   12  Auto-S6   2WD  Gasoline
# 10   ASTON MARTIN DB9 Volante    5.9   12    Man-6   2WD  Gasoline
# 11   ASTON MARTIN DB9 Volante    5.9   12  Auto-S6   2WD  Gasoline
# 12    ASTON MARTIN V8 Vantage    4.3    8    Man-6   2WD  Gasoline
# ...

# %% [markdown]
# ### Q3: What are the characteristics of SmartWay vehicles? Have they changed over time?

# %%
df_08.query("smartway == 'yes'").describe()
# Out:
#             displ         cyl  air_pollution_score    city_mpg     hwy_mpg  \
# count  380.000000  380.000000           380.000000  380.000000  380.000000
# mean     2.602895    4.826316             7.365789   20.984211   28.413158
# std      0.623436    1.002025             1.148195    3.442672    3.075194
# min      1.300000    4.000000             6.000000   17.000000   22.000000
# 25%      2.275000    4.000000             7.000000   19.000000   26.000000
# 50%      2.400000    4.000000             7.000000   20.000000   28.000000
# 75%      3.000000    6.000000             7.000000   22.000000   30.000000
# max      5.000000    8.000000             9.500000   48.000000   45.000000
#
#           cmb_mpg  greenhouse_gas_score
# count  380.000000            380.000000
# mean    23.736842              6.868421
# std      3.060379              0.827338
# min     20.000000              6.000000
# 25%     22.000000              6.000000
# 50%     23.000000              7.000000
# ...

# %%
df_08.query("smartway != 'yes'").describe()
# Out:
#             displ         cyl  air_pollution_score    city_mpg     hwy_mpg  \
# count  607.000000  607.000000           607.000000  607.000000  607.000000
# mean     4.056837    6.771005             6.293245   15.133443   21.299835
# std      1.203933    1.882335             0.551479    2.564736    3.366852
# min      1.300000    2.000000             4.000000    8.000000   13.000000
# 25%      3.200000    6.000000             6.000000   13.000000   19.000000
# 50%      3.800000    6.000000             6.000000   15.000000   21.000000
# 75%      4.900000    8.000000             7.000000   17.000000   24.000000
# max      8.400000   16.000000             9.500000   21.000000   28.000000
#
#           cmb_mpg  greenhouse_gas_score
# count  607.000000            607.000000
# mean    17.316310              4.149918
# std      2.766868              1.629634
# min     10.000000              0.000000
# 25%     15.000000              3.000000
# 50%     18.000000              5.000000
# ...

# %%
"In 2008, the smart vehicle recorded lower air_pollution_score "
